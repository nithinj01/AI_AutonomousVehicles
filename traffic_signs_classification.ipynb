# %% [markdown]
# ### **Import Libraries**

# %%
import keras
from keras.models import Sequential
from keras.layers.convolutional import Conv2D ,MaxPooling2D
from keras.layers import Dense, Dropout, Flatten
from keras.optimizers import Adam
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import pickle
import pandas as pd
import numpy as np
import random
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ### **Import Dataset and Explore it**

# %%
# cloning repo containing the traffic sign dataset
# !git clone https://bitbucket.org/jadslim/german-traffic-signs
# Out:
# Cloning into 'german-traffic-signs'...
# remote: Counting objects: 6, done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 6 (delta 0), reused 0 (delta 0)
# Unpacking objects: 100% (6/6), done.

# %%
# list dataset contents

# !ls german-traffic-signs
# Out:
# signnames.csv  test.p  train.p	valid.p

# %%
#load the dataset

data = pd.read_csv('german-traffic-signs/signnames.csv')

# %%
data
# Out:
#     ClassId                                           SignName
# 0         0                               Speed limit (20km/h)
# 1         1                               Speed limit (30km/h)
# 2         2                               Speed limit (50km/h)
# 3         3                               Speed limit (60km/h)
# 4         4                               Speed limit (70km/h)
# 5         5                               Speed limit (80km/h)
# 6         6                        End of speed limit (80km/h)
# 7         7                              Speed limit (100km/h)
# 8         8                              Speed limit (120km/h)
# 9         9                                         No passing
# 10       10       No passing for vechiles over 3.5 metric tons
# 11       11              Right-of-way at the next intersection
# 12       12                                      Priority road
# 13       13                                              Yield
# 14       14                                               Stop
# 15       15                                        No vechiles
# 16       16           Vechiles over 3.5 metric tons prohibited
# 17       17                                           No entry
# 18       18                                    General caution
# 19       19                        Dangerous curve to the left
# 20       20                       Dangerous curve to the right
# 21       21                                       Double curve
# 22       22                                         Bumpy road
# 23       23                                      Slippery road
# 24       24                          Road narrows on the right
# 25       25                                          Road work
# 26       26                                    Traffic signals
# 27       27                                        Pedestrians
# 28       28                                  Children crossing
# 29       29                                  Bicycles crossing
# 30       30                                 Beware of ice/snow
# 31       31                              Wild animals crossing
# 32       32                End of all speed and passing limits
# 33       33                                   Turn right ahead
# 34       34                                    Turn left ahead
# 35       35                                         Ahead only
# 36       36                               Go straight or right
# 37       37                                Go straight or left
# 38       38                                         Keep right
# 39       39                                          Keep left
# 40       40                               Roundabout mandatory
# 41       41                                  End of no passing
# 42       42  End of no passing by vechiles over 3.5 metric ...

# %%
#loading pickled dataset

with open("german-traffic-signs/train.p",mode='rb') as training:
  train = pickle.load(training)

with open("german-traffic-signs/valid.p",mode='rb') as validation:
  valid = pickle.load(validation)

with open("german-traffic-signs/test.p",mode='rb') as testing:
  test = pickle.load(testing)

# %%
X_train , y_train = train['features'], train['labels']
X_validation , y_validation = valid['features'], valid['labels']
X_test , y_test = test['features'], test['labels']

# %%
print(X_train.shape)
print(X_validation.shape)
print(X_test.shape)
# Out:
# (34799, 32, 32, 3)
# (4410, 32, 32, 3)
# (12630, 32, 32, 3)

# %%
index = np.random.randint(1,len(X_train))
plt.imshow(X_train[index])
print("image label={}".format(y_train[index]))
# Out:
# image label=4

# %% [markdown]
# # Image Pre-processing

# %% [markdown]
# # 1. converting to grayscale
# # 2. Histogram Equalization
# # 3. Normalization

# %%
# shuffle the data
from sklearn.utils import shuffle
X_train , y_train = shuffle(X_train,y_train)

# %%
def preprocessing(img):
  #convert to grayscale
  img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
  #Applying histogram equalization
  img = cv2.equalizeHist(img)
  #Normalization
  img = img/255
  return img

# %%
X_train_processed = np.array(list(map(preprocessing,X_train)))
X_validation_processed = np.array(list(map(preprocessing,X_validation)))
X_test_processed = np.array(list(map(preprocessing,X_test)))

# %%
X_train_processed = X_train_processed.reshape(34799,32,32,1)
X_test_processed = X_test_processed.reshape(12630,32,32,1)
X_validation_processed = X_validation_processed.reshape(4410,32,32,1)

# %%
print(X_train_processed.shape)
print(X_test_processed.shape)
print(X_validation_processed.shape)
# Out:
# (34799, 32, 32, 1)
# (12630, 32, 32, 1)
# (4410, 32, 32, 1)

# %%
i= random.randint(1,len(X_train))
plt.imshow(X_train_processed[i].squeeze(),cmap='gray')
plt.figure()
plt.imshow(X_train[i].squeeze())

# %% [markdown]
# # Build Deep Convolution Neural Network Model

# %%
model = Sequential()
# add the convolutional layer
# filters, size of filters,input_shape,activation_function
model.add(Conv2D(32,(5,5),activation='relu',input_shape=(32,32,1)))

# pooling layer
model.add(MaxPooling2D(pool_size=(2,2)))

# place a dropout layer
model.add(Dropout(0.25))

# add another convolutional layer
model.add(Conv2D(64,(5,5),activation='relu'))

# pooling layer
model.add(MaxPooling2D(pool_size=(2,2)))

# Flatten the image to 1 dimensional array
model.add(Flatten())

# add a dense layer : amount of nodes, activation
model.add(Dense(256,activation='relu'))

# place a dropout layer
# 0.5 drop out rate is recommended, half input nodes will be dropped at each update
model.add(Dropout(0.5))

# defining the ouput layer of our network
model.add(Dense(43,activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 28, 28, 32)        832
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 10, 10, 64)        51264
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               409856
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 43)                11051
# =================================================================
# Total params: 473,003
# Trainable params: 473,003
# Non-trainable params: 0
# _________________________________________________________________

# %%
#compile our model
model.compile(Adam(lr=0.0001),loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(X_train_processed,
                    y_train,
                    batch_size=500,
                    epochs=50,
                    verbose=1,
                    validation_data=(X_validation_processed,y_validation))
# Out:
# Train on 34799 samples, validate on 4410 samples
# Epoch 1/50
# 34799/34799 [==============================] - 8s 242us/step - loss: 3.5531 - accuracy: 0.0668 - val_loss: 3.4725 - val_accuracy: 0.1655
# Epoch 2/50
# 34799/34799 [==============================] - 2s 63us/step - loss: 3.2618 - accuracy: 0.1694 - val_loss: 3.0531 - val_accuracy: 0.3025
# Epoch 3/50
# 34799/34799 [==============================] - 2s 62us/step - loss: 2.7252 - accuracy: 0.3177 - val_loss: 2.4122 - val_accuracy: 0.4331
# Epoch 4/50
# 34799/34799 [==============================] - 2s 63us/step - loss: 2.2393 - accuracy: 0.4124 - val_loss: 1.9678 - val_accuracy: 0.4841
# Epoch 5/50
# 34799/34799 [==============================] - 2s 63us/step - loss: 1.9033 - accuracy: 0.4815 - val_loss: 1.6379 - val_accuracy: 0.5571
# Epoch 6/50
# 34799/34799 [==============================] - 2s 64us/step - loss: 1.6419 - accuracy: 0.5382 - val_loss: 1.3954 - val_accuracy: 0.6136
# Epoch 7/50
# 34799/34799 [==============================] - 2s 63us/step - loss: 1.4485 - accuracy: 0.5837 - val_loss: 1.2276 - val_accuracy: 0.6728
# Epoch 8/50
# 34799/34799 [==============================] - 2s 63us/step - loss: 1.3004 - accuracy: 0.6193 - val_loss: 1.0769 - val_accuracy: 0.7032
# Epoch 9/50
# 34799/34799 [==============================] - 2s 64us/step - loss: 1.1801 - accuracy: 0.6497 - val_loss: 0.9570 - val_accuracy: 0.7481
# Epoch 10/50
# 34799/34799 [==============================] - 2s 63us/step - loss: 1.0798 - accuracy: 0.6761 - val_loss: 0.8670 - val_accuracy: 0.7692
# Epoch 11/50
# 34799/34799 [==============================] - 2s 63us/step - loss: 0.9919 - accuracy: 0.7064 - val_loss: 0.7965 - val_accuracy: 0.7871
# Epoch 12/50
# 34799/34799 [==============================] - 2s 63us/step - loss: 0.9097 - accuracy: 0.7273 - val_loss: 0.7408 - val_accuracy: 0.7973
# Epoch 13/50
# 34799/34799 [==============================] - 2s 63us/step - loss: 0.8504 - accuracy: 0.7435 - val_loss: 0.6846 - val_accuracy: 0.8120
# Epoch 14/50
# 34799/34799 [==============================] - 2s 63us/step - loss: 0.7886 - accuracy: 0.7656 - val_loss: 0.6380 - val_accuracy: 0.8247
# Epoch 15/50
# 34799/34799 [==============================] - 2s 62us/step - loss: 0.7389 - accuracy: 0.7748 - val_loss: 0.6072 - val_accuracy: 0.8317
# Epoch 16/50
# 34799/34799 [==============================] - 2s 63us/step - loss: 0.6881 - accuracy: 0.7925 - val_loss: 0.5686 - val_accuracy: 0.8381
# Epoch 17/50
# 34799/34799 [==============================] - 2s 63us/step - loss: 0.6513 - accuracy: 0.8036 - val_loss: 0.5385 - val_accuracy: 0.8551
# Epoch 18/50
# 34799/34799 [==============================] - 2s 62us/step - loss: 0.6063 - accuracy: 0.8177 - val_loss: 0.5154 - val_accuracy: 0.8558
# Epoch 19/50
# 34799/34799 [==============================] - 2s 63us/step - loss: 0.5779 - accuracy: 0.8254 - val_loss: 0.4867 - val_accuracy: 0.8646
# Epoch 20/50
# 34799/34799 [==============================] - 2s 64us/step - loss: 0.5451 - accuracy: 0.8352 - val_loss: 0.4672 - val_accuracy: 0.8687
# Epoch 21/50
# 34799/34799 [==============================] - 2s 64us/step - loss: 0.5160 - accuracy: 0.8449 - val_loss: 0.4424 - val_accuracy: 0.8728
# Epoch 22/50
# 34799/34799 [==============================] - 2s 63us/step - loss: 0.4963 - accuracy: 0.8527 - val_loss: 0.4235 - val_accuracy: 0.8837
# Epoch 23/50
# 34799/34799 [==============================] - 2s 63us/step - loss: 0.4706 - accuracy: 0.8590 - val_loss: 0.4099 - val_accuracy: 0.8878
# Epoch 24/50
# 34799/34799 [==============================] - 2s 63us/step - loss: 0.4448 - accuracy: 0.8670 - val_loss: 0.3965 - val_accuracy: 0.8873
# Epoch 25/50
# 34799/34799 [==============================] - 2s 63us/step - loss: 0.4271 - accuracy: 0.8742 - val_loss: 0.3841 - val_accuracy: 0.8925
# Epoch 26/50
# 34799/34799 [==============================] - 2s 62us/step - loss: 0.4104 - accuracy: 0.8775 - val_loss: 0.3816 - val_accuracy: 0.8875
# Epoch 27/50
# 34799/34799 [==============================] - 2s 62us/step - loss: 0.3952 - accuracy: 0.8813 - val_loss: 0.3553 - val_accuracy: 0.9011
# Epoch 28/50
# 34799/34799 [==============================] - 2s 63us/step - loss: 0.3721 - accuracy: 0.8901 - val_loss: 0.3552 - val_accuracy: 0.8975
# Epoch 29/50
# 34799/34799 [==============================] - 2s 62us/step - loss: 0.3649 - accuracy: 0.8896 - val_loss: 0.3422 - val_accuracy: 0.9023
# Epoch 30/50
# 34799/34799 [==============================] - 2s 62us/step - loss: 0.3460 - accuracy: 0.8981 - val_loss: 0.3297 - val_accuracy: 0.9077
# Epoch 31/50
# 34799/34799 [==============================] - 2s 62us/step - loss: 0.3326 - accuracy: 0.9006 - val_loss: 0.3173 - val_accuracy: 0.9086
# Epoch 32/50
# 34799/34799 [==============================] - 2s 63us/step - loss: 0.3159 - accuracy: 0.9061 - val_loss: 0.3171 - val_accuracy: 0.9066
# Epoch 33/50
# 34799/34799 [==============================] - 2s 63us/step - loss: 0.3060 - accuracy: 0.9099 - val_loss: 0.3116 - val_accuracy: 0.9079
# Epoch 34/50
# 34799/34799 [==============================] - 2s 63us/step - loss: 0.2957 - accuracy: 0.9124 - val_loss: 0.2995 - val_accuracy: 0.9111
# Epoch 35/50
# 34799/34799 [==============================] - 2s 63us/step - loss: 0.2850 - accuracy: 0.9159 - val_loss: 0.3090 - val_accuracy: 0.9084
# Epoch 36/50
# 34799/34799 [==============================] - 2s 63us/step - loss: 0.2762 - accuracy: 0.9180 - val_loss: 0.2911 - val_accuracy: 0.9127
# Epoch 37/50
# 34799/34799 [==============================] - 2s 64us/step - loss: 0.2665 - accuracy: 0.9198 - val_loss: 0.2760 - val_accuracy: 0.9170
# Epoch 38/50
# 34799/34799 [==============================] - 2s 64us/step - loss: 0.2555 - accuracy: 0.9242 - val_loss: 0.2680 - val_accuracy: 0.9215
# Epoch 39/50
# 34799/34799 [==============================] - 2s 64us/step - loss: 0.2439 - accuracy: 0.9291 - val_loss: 0.2730 - val_accuracy: 0.9197
# Epoch 40/50
# 34799/34799 [==============================] - 2s 64us/step - loss: 0.2423 - accuracy: 0.9294 - val_loss: 0.2707 - val_accuracy: 0.9184
# Epoch 41/50
# 34799/34799 [==============================] - 2s 64us/step - loss: 0.2305 - accuracy: 0.9337 - val_loss: 0.2555 - val_accuracy: 0.9243
# Epoch 42/50
# 34799/34799 [==============================] - 2s 64us/step - loss: 0.2242 - accuracy: 0.9356 - val_loss: 0.2500 - val_accuracy: 0.9286
# Epoch 43/50
# 34799/34799 [==============================] - 2s 64us/step - loss: 0.2159 - accuracy: 0.9370 - val_loss: 0.2488 - val_accuracy: 0.9293
# Epoch 44/50
# 34799/34799 [==============================] - 2s 62us/step - loss: 0.2107 - accuracy: 0.9368 - val_loss: 0.2447 - val_accuracy: 0.9261
# Epoch 45/50
# 34799/34799 [==============================] - 2s 63us/step - loss: 0.2051 - accuracy: 0.9405 - val_loss: 0.2394 - val_accuracy: 0.9317
# Epoch 46/50
# 34799/34799 [==============================] - 2s 63us/step - loss: 0.1992 - accuracy: 0.9418 - val_loss: 0.2383 - val_accuracy: 0.9324
# Epoch 47/50
# 34799/34799 [==============================] - 2s 63us/step - loss: 0.1895 - accuracy: 0.9450 - val_loss: 0.2373 - val_accuracy: 0.9295
# Epoch 48/50
# 34799/34799 [==============================] - 2s 64us/step - loss: 0.1890 - accuracy: 0.9438 - val_loss: 0.2313 - val_accuracy: 0.9322
# Epoch 49/50
# 34799/34799 [==============================] - 2s 62us/step - loss: 0.1823 - accuracy: 0.9469 - val_loss: 0.2268 - val_accuracy: 0.9361
# Epoch 50/50
# 34799/34799 [==============================] - 2s 62us/step - loss: 0.1776 - accuracy: 0.9476 - val_loss: 0.2261 - val_accuracy: 0.9336

# %% [markdown]
# # Evaluate Performance of the model

# %%
score = model.evaluate(X_test_processed,y_test)
print('Test accuracy',score[1])
# Out:
# 12630/12630 [==============================] - 1s 96us/step
# Test accuracy 0.9139350652694702

# %%
history.history.keys()
# Out:
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy'])

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['training','validation'])
plt.title('Training and validation losses')
plt.xlabel('epochs')
# Out:
# Text(0.5, 0, 'epochs')

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['training','validation'])
plt.title('Training and validation accuracy')
plt.xlabel('epochs')
# Out:
# Text(0.5, 0, 'epochs')

# %%
prediction = model.predict_classes(X_test_processed)
y_true_label= y_test

# %%
from sklearn.metrics import confusion_matrix
matrix = confusion_matrix(y_true_label,prediction)
plt.figure(figsize=(20,20))
sns.heatmap(matrix,annot=True)

# %%
L=6
W=6
fig , axes = plt.subplots(L,W,figsize=(12,12))
axes = axes.ravel()
for i in range(0,L*W):
  axes[i].imshow(X_test[i])
  axes[i].set_title('Prediction ={}\n True={}'.format(prediction[i],y_true_label[i]))
  axes[i].axis('off')
plt.subplots_adjust(wspace=1)

# %%
model.save('my_model.h5')
